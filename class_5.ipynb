# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarasayreh/AIHUB/blob/main/class_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/traffic.csv")
df
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0     12:00:00 AM    10         Tuesday        31          0         4
# 1     12:15:00 AM    10         Tuesday        49          0         3
# 2     12:30:00 AM    10         Tuesday        46          0         3
# 3     12:45:00 AM    10         Tuesday        51          0         2
# 4      1:00:00 AM    10         Tuesday        57          6        15
# ...           ...   ...             ...       ...        ...       ...
# 2971  10:45:00 PM     9        Thursday        16          3         1
# 2972  11:00:00 PM     9        Thursday        11          0         1
# 2973  11:15:00 PM     9        Thursday        15          4         1
# 2974  11:30:00 PM     9        Thursday        16          5         0
# 2975  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount  Total Traffic Situation
# 0              4     39               low
# ...

# %%
df.shape
# Out:
# (2976, 9)

# %%
df.isnull().sum()
# Out:
# Time                 0
# Date                 0
# Day of the week      0
# CarCount             0
# BikeCount            0
# BusCount             0
# TruckCount           0
# Total                0
# Traffic Situation    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Traffic Situation'].value_counts()
# Out:
# Traffic Situation
# normal    1669
# heavy      682
# high       321
# low        304
# Name: count, dtype: int64

# %%
df['Day of the week'].value_counts()
# Out:
# Day of the week
# Tuesday      480
# Wednesday    480
# Thursday     480
# Friday       384
# Saturday     384
# Sunday       384
# Monday       384
# Name: count, dtype: int64

# %%
day={'Saturday':1,'Sunday':2,'Monday':3,'Tuesday':4,'Wednesday':5,'Thursday':6,'Friday':7}
df['Day of the week']=df['Day of the week'].replace(day)
# Out:
# /tmp/ipython-input-3675460426.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Day of the week']=df['Day of the week'].replace(day)

# %%
df
# Out:
#              Time  Date  Day of the week  CarCount  BikeCount  BusCount  \
# 0     12:00:00 AM    10                4        31          0         4
# 1     12:15:00 AM    10                4        49          0         3
# 2     12:30:00 AM    10                4        46          0         3
# 3     12:45:00 AM    10                4        51          0         2
# 4      1:00:00 AM    10                4        57          6        15
# ...           ...   ...              ...       ...        ...       ...
# 2971  10:45:00 PM     9                6        16          3         1
# 2972  11:00:00 PM     9                6        11          0         1
# 2973  11:15:00 PM     9                6        15          4         1
# 2974  11:30:00 PM     9                6        16          5         0
# 2975  11:45:00 PM     9                6        14          3         1
#
#       TruckCount  Total Traffic Situation
# 0              4     39               low
# ...

# %%
df.dtypes
# Out:
# Time                 object
# Date                  int64
# Day of the week       int64
# CarCount              int64
# BikeCount             int64
# BusCount              int64
# TruckCount            int64
# Total                 int64
# Traffic Situation    object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
for col in df.columns:
  plt.figure(figsize=(8,5))
  plt.hist(df[col].dropna(),bins=10,color="red",edgecolor="black")
  plt.xlabel(col)
  plt.ylabel("frequency")
  plt.show()

# %%
plt.pie(df['Traffic Situation'].value_counts(),labels=df['Traffic Situation'].value_counts().index,autopct='%1.1f%%')
plt.title('Traffic Situation distribution')
plt.show()

# %%
group=df[['CarCount','BikeCount','BusCount','TruckCount']].sum()
plt.figure(figsize=(8,5))
plt.pie(group,labels=group.index,autopct='%1.1f%%')
plt.title('vichles type dirtibution')
plt.show()

# %%
avg=df.groupby('Day of the week')['Total'].mean()
plt.figure(figsize=(8,5))
plt.bar(avg.index,avg.values,color='green')
plt.xlabel('Day of the week')
plt.ylabel('Average Traffic')
plt.title('Average Traffic by Day of the Week')
plt.show()

# %%
df
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0     12:00:00 AM    10         Tuesday        31          0         4
# 1     12:15:00 AM    10         Tuesday        49          0         3
# 2     12:30:00 AM    10         Tuesday        46          0         3
# 3     12:45:00 AM    10         Tuesday        51          0         2
# 4      1:00:00 AM    10         Tuesday        57          6        15
# ...           ...   ...             ...       ...        ...       ...
# 2971  10:45:00 PM     9        Thursday        16          3         1
# 2972  11:00:00 PM     9        Thursday        11          0         1
# 2973  11:15:00 PM     9        Thursday        15          4         1
# 2974  11:30:00 PM     9        Thursday        16          5         0
# 2975  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount  Total Traffic Situation
# 0              4     39               low
# ...

# %%
vichles_count=df.groupby('Day of the week')[['CarCount','BikeCount','BusCount','TruckCount']].sum()
plt.figure(figsize=(8,5))
vichles_count.plot(kind='bar')
plt.title('vichles count')
plt.xlabel('Day of the week')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
colors=sns.color_palette('pastel')
plt.figure(figsize=(8,5))
plt.pie(df['Traffic Situation'].value_counts(),labels=df['Traffic Situation'].value_counts().index,autopct='%1.1f%%',colors=colors)
plt.title('Traffic Situation distribution')
plt.show()

# %%
df
# Out:
#              Time  Date Day of the week  CarCount  BikeCount  BusCount  \
# 0     12:00:00 AM    10         Tuesday        31          0         4
# 1     12:15:00 AM    10         Tuesday        49          0         3
# 2     12:30:00 AM    10         Tuesday        46          0         3
# 3     12:45:00 AM    10         Tuesday        51          0         2
# 4      1:00:00 AM    10         Tuesday        57          6        15
# ...           ...   ...             ...       ...        ...       ...
# 2971  10:45:00 PM     9        Thursday        16          3         1
# 2972  11:00:00 PM     9        Thursday        11          0         1
# 2973  11:15:00 PM     9        Thursday        15          4         1
# 2974  11:30:00 PM     9        Thursday        16          5         0
# 2975  11:45:00 PM     9        Thursday        14          3         1
#
#       TruckCount  Total Traffic Situation
# 0              4     39               low
# ...

# %%
columns=['CarCount','BikeCount','BusCount','TruckCount']
sns.boxplot(data=df[columns])
plt.title('boxplot')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='Traffic Situation',y='CarCount',data=df)
plt.xlabel('Traffic Situation')
plt.ylabel('CarCount')
plt.show()

# %%
sns.lineplot(data=df,x='Time',y='CarCount')
plt.show()

# %%
numeric_df = df.select_dtypes(include=np.number)
corr = numeric_df.corr()
sns.heatmap(corr, annot=True, fmt='.2f')
plt.show()
